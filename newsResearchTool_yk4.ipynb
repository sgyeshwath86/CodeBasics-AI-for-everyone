# %%
pip install langchain

# %%
from langchain.document_loaders import TextLoader

# %%
pip install -U langchain-community

# %%
#Example for using text loader

# %%
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader('nvda_news_1.txt')

# %%
data = loader.load()
data

# %%
#Example for using CSV loader

# %%
from langchain.document_loaders import CSVLoader

# %%
loader = CSVLoader('movies.csv',source_column='title')
dataCsv = loader.load()

# %%
dataCsv[2].metadata

# %%
pip install unstructured libmagic python-magic python-magic-bin

# %%
#How to use URL loader to get the data from URLs

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
loaderURL = UnstructuredURLLoader(urls=['https://www.moneycontrol.com/news/business/tata-motors-mahindra-gain-certificates-for-production-linked-payouts-11281691.html',
                           'https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html'])

# %%
urlData = loaderURL.load()
len(urlData)

# %%
urlData[0].metadata

# %%
urlData[0]

# %%
# Create chunks of data from the full article so that you can reduce the data fed into the openAI token limit
#Steps:
#Divide the article into chunks closer to the token limit of the API
# Perform merge on the split chunks to be exactly less than the limit
# Create overlap b/w chunks so that there is a transfer of context b/w individual chunks

# %%
# Testing a text splitter from langchain
from langchain.text_splitter import CharacterTextSplitter

# %%
# The chunk size and overlap are entered as parameters
splitter = CharacterTextSplitter(separator='\n',
                     chunk_size=200,
                     chunk_overlap=0)

# %%
# Random text from wikipedia
text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %%
# performing the split yields chunk sizes which are >200 even though we had specified it to be <200
chunks = splitter.split_text(text)

# %%
chunks

# %%
# The chunk size are not alwways <200 hence the character text splitter is not efficient
for chunk in chunks:
    print(len(chunk))

# %%
# Lets explore another splitter, Recursive Character Text Splitter
from langchain.text_splitter import RecursiveCharacterTextSplitter
r_splitter = RecursiveCharacterTextSplitter(separators=['\n\n','\n',' '],
                              chunk_size=200,
                              chunk_overlap=0)
chunks = r_splitter.split_text(text)
len(chunks)

# %%
for chunk in chunks:
    print(len(chunk))

# %%
# Convert the chunks into embeddings

# %%
# Store the vectors in a vector database (FAISS: Facebook AI Similarity Search)
# pip install faiss-cpu
# pip install sentence-transformers

# %%
pip install faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\ykumar4\AppData\Roaming\Python\Python312\Scripts\CodeBasics\IndustryProjects\NewsResearchTool\2_news_research_tool_project\notebooks\sample_text.csv')

# %%
df.shape
# Out:
# (8, 2)

# %%
df
# Out:
#                                                 text category
# 0      Meditation and yoga can improve mental health   Health
# 1  Fruits, whole grains and vegetables helps cont...   Health
# 2  These are the latest fashion trends for this week  Fashion
# 3  Vibrant color jeans for male are becoming a trend  Fashion
# 4                 The concert starts at 7 PM tonight    Event
# 5  Navaratri dandiya program at Expo center in Mu...    Event
# 6  Exciting vacation destinations for your next trip   Travel
# 7  Maldives and Srilanka are gaining popularity i...   Travel

# %%
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer('all-mpnet-base-v2')
# Out:
# No sentence-transformers model found with name sentence-transformers/all-mpnet-base-v2. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2', cache_folder='./models')
# Out:
# No sentence-transformers model found with name sentence-transformers/all-mpnet-base-v2. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
pip install --upgrade certifi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade urllib3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
encoder = SentenceTransformer('all-mpnet-base-v2')
# Out:
# No sentence-transformers model found with name sentence-transformers/all-mpnet-base-v2. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
model = SentenceTransformer('C:/Users/ykumar4/AppData/Roaming/Python/Python312/Scripts/CodeBasics/IndustryProjects/NewsResearchTool')

# %%
git clone https://gist.github.com/padeoe/697678ab8e528b85a2a7bddafea1fa4f hfd
cd hfd
chmod +x hfd.sh
./hfd.sh sentence-transformers/all-mpnet-base-v2 --tool wget --local-dir ./all-mpnet-base-v2
# Out:
#   Cell In[14], line 1
#     git clone https://gist.github.com/padeoe/697678ab8e528b85a2a7bddafea1fa4f hfd
#                                                   ^
# SyntaxError: invalid decimal literal
